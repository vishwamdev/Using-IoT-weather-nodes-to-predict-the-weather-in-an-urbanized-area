# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import time
from datetime import datetime, timezone
import pytz
from math import radians, sin, cos, sqrt, atan2  # For distance calculation

# Define weather station coordinates (only two)
stations_info = {
    'WS1': {'latitude': 7.0193689, 'longitude': 79.9001577},
    'WS2': {'latitude': 7.0193110, 'longitude': 79.9002777}
}

# Power parameter for IDW
p = 2

# Google Sheets credentials and access
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("your_google_credentials1.json", scope)
client = gspread.authorize(creds)

# Google Sheets references (only two + pre2)
sheets_info = {
    'WS1': client.open("WS1").sheet1,
    'WS2': client.open("WS2").sheet1,
    'pre2': client.open("pre2").sheet1  
}

# Set your local timezone
local_tz = pytz.timezone('Asia/Colombo')

# Expected headers
WS_EXPECTED_HEADERS = ['Date', 'Time', 'Temperature', 'Humidity', 'Air Pressure', 'Air Quality', 'Rain Status']
PD_EXPECTED_HEADERS = ['Date', 'Time', 'Latitude', 'Longitude', 'Temperature', 'Humidity', 'Air Pressure', 'Air Quality', 'Rain Status']

# Get user input
def get_user_location():
    while True:
        try:
            lat = float(input("Enter the latitude of the target location: "))
            lon = float(input("Enter the longitude of the target location: "))
            if -90 <= lat <= 90 and -180 <= lon <= 180:
                return {'latitude': lat, 'longitude': lon}
            else:
                print("Invalid latitude/longitude. Please enter valid coordinates.")
        except ValueError:
            print("Invalid input. Please enter numerical values.")

# Calculate distance using Haversine formula
def calculate_distance(lat1, lon1, lat2, lon2):
    R = 6371.0  # Earth radius in km
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# Fetch latest data
def fetch_latest_data(sheet):
    expected_headers = PD_EXPECTED_HEADERS if sheet.title == sheets_info['pre2'].title else WS_EXPECTED_HEADERS
    try:
        records = sheet.get_all_records(expected_headers=expected_headers)
        return records[-1] if records else None
    except Exception as e:
        print(f"Error fetching latest data from {sheet.title}: {e}")
        return None

# IDW for numerical values
def calculate_idw_prediction(latest_data, distances, param):
    weighted_sum = 0
    weight_sum = 0
    for location, distance in distances.items():
        value = latest_data[location][param]
        weight = 1 / (distance ** p)
        weighted_sum += value * weight
        weight_sum += weight
    return round(weighted_sum / weight_sum, 2)

# Categorical value prediction (majority vote with weights)
def predict_categorical(latest_data, distances, param):
    weights = {}
    for location, distance in distances.items():
        category = latest_data[location][param]
        weight = 1 / (distance ** p)
        weights[category] = weights.get(category, 0) + weight
    return max(weights, key=weights.get)

# Get local time
def get_local_time():
    utc_time = datetime.now(timezone.utc)
    local_time = utc_time.astimezone(local_tz)
    return local_time.strftime("%Y-%m-%d %H:%M:%S")

# Main update loop
def update_predictions():
    target_location = get_user_location()

    while True:
        current_time = get_local_time()
        latest_data = {}
        distances = {}

        # Calculate distances
        for location, info in stations_info.items():
            distances[location] = calculate_distance(
                info['latitude'], info['longitude'],
                target_location['latitude'], target_location['longitude']
            )

        # Fetch latest sensor data
        data_ready = True
        for location, sheet in sheets_info.items():
            if location == 'pre2':
                continue
            latest_entry = fetch_latest_data(sheet)
            if latest_entry:
                try:
                    latest_data[location] = {
                        'Temperature': float(latest_entry['Temperature'].replace('C', '').strip()),
                        'Humidity': float(latest_entry['Humidity'].replace('%', '').strip()),
                        'Air Pressure': float(latest_entry['Air Pressure'].replace('hPa', '').strip()),
                        'Air Quality': latest_entry['Air Quality'].strip(),
                        'Rain Status': latest_entry['Rain Status'].strip()
                    }
                except (ValueError, KeyError) as e:
                    print(f"[{location}] Data unreadable: {e}. Waiting for valid data...")
                    data_ready = False
                    break
            else:
                print(f"[{location}] No data found. Waiting for next update...")
                data_ready = False
                break

        if not data_ready:
            time.sleep(10)
            continue

        # Generate predictions
        predictions = {
            'Temperature': calculate_idw_prediction(latest_data, distances, 'Temperature'),
            'Humidity': calculate_idw_prediction(latest_data, distances, 'Humidity'),
            'Air Pressure': calculate_idw_prediction(latest_data, distances, 'Air Pressure'),
            'Air Quality': predict_categorical(latest_data, distances, 'Air Quality'),
            'Rain Status': predict_categorical(latest_data, distances, 'Rain Status')
        }

        # Write prediction to sheet
        pd_sheet = sheets_info['pre2']
        local_date, local_time_str = get_local_time().split(" ")
        new_row = [
            local_date, local_time_str,
            target_location['latitude'], target_location['longitude'],
            predictions['Temperature'], predictions['Humidity'], predictions['Air Pressure'],
            predictions['Air Quality'], predictions['Rain Status']
        ]
        pd_sheet.append_row(new_row)

        print(f"✅ Updated Predictions for Location ({target_location['latitude']}, {target_location['longitude']}) at {current_time}: {predictions}")
        time.sleep(35)

# Start predictions
try:
    update_predictions()
except KeyboardInterrupt:
    print("Prediction update process stopped.")
# Out:
# Enter the latitude of the target location: 7.0195700
# Enter the longitude of the target location: 79.9002561
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:05:38: {'Temperature': 32.34, 'Humidity': 60.28, 'Air Pressure': 1007.93, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:06:20: {'Temperature': 32.67, 'Humidity': 60.15, 'Air Pressure': 1007.93, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:06:59: {'Temperature': 32.59, 'Humidity': 59.58, 'Air Pressure': 1007.94, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:07:40: {'Temperature': 32.32, 'Humidity': 59.49, 'Air Pressure': 1007.96, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:08:20: {'Temperature': 32.19, 'Humidity': 59.44, 'Air Pressure': 1007.96, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:09:00: {'Temperature': 32.77, 'Humidity': 59.3, 'Air Pressure': 1007.96, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:09:41: {'Temperature': 32.31, 'Humidity': 59.39, 'Air Pressure': 1007.95, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:10:20: {'Temperature': 32.17, 'Humidity': 59.26, 'Air Pressure': 1007.96, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:10:59: {'Temperature': 32.68, 'Humidity': 58.83, 'Air Pressure': 1008.01, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:11:39: {'Temperature': 32.5, 'Humidity': 58.31, 'Air Pressure': 1007.97, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:12:21: {'Temperature': 32.68, 'Humidity': 58.28, 'Air Pressure': 1007.99, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:13:01: {'Temperature': 32.81, 'Humidity': 58.35, 'Air Pressure': 1008.0, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:13:41: {'Temperature': 32.62, 'Humidity': 58.01, 'Air Pressure': 1007.98, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:14:22: {'Temperature': 32.23, 'Humidity': 58.24, 'Air Pressure': 1007.96, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:15:04: {'Temperature': 32.37, 'Humidity': 58.36, 'Air Pressure': 1007.98, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:15:43: {'Temperature': 32.74, 'Humidity': 58.33, 'Air Pressure': 1007.99, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:16:24: {'Temperature': 32.67, 'Humidity': 58.41, 'Air Pressure': 1007.98, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:17:04: {'Temperature': 32.41, 'Humidity': 58.71, 'Air Pressure': 1007.97, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:17:44: {'Temperature': 32.45, 'Humidity': 58.8, 'Air Pressure': 1007.96, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18:18:23: {'Temperature': 32.75, 'Humidity': 59.14, 'Air Pressure': 1007.97, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 18
 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:08:25: {'Temperature': 32.78, 'Humidity': 61.73, 'Air Pressure': 1008.45, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:09:06: {'Temperature': 32.8, 'Humidity': 61.66, 'Air Pressure': 1008.44, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:09:46: {'Temperature': 32.48, 'Humidity': 61.79, 'Air Pressure': 1008.44, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:10:27: {'Temperature': 32.63, 'Humidity': 61.59, 'Air Pressure': 1008.43, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:11:07: {'Temperature': 32.56, 'Humidity': 61.94, 'Air Pressure': 1008.43, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:11:47: {'Temperature': 32.69, 'Humidity': 62.04, 'Air Pressure': 1008.43, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:12:27: {'Temperature': 32.75, 'Humidity': 62.37, 'Air Pressure': 1008.43, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:13:07: {'Temperature': 32.53, 'Humidity': 62.59, 'Air Pressure': 1008.46, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:13:47: {'Temperature': 32.56, 'Humidity': 62.53, 'Air Pressure': 1008.44, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:14:31: {'Temperature': 32.75, 'Humidity': 62.92, 'Air Pressure': 1008.44, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:15:13: {'Temperature': 32.41, 'Humidity': 62.58, 'Air Pressure': 1008.43, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:16:04: {'Temperature': 32.47, 'Humidity': 62.65, 'Air Pressure': 1008.47, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:17:10: {'Temperature': 32.51, 'Humidity': 62.31, 'Air Pressure': 1008.53, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-18 19:18:17: {'Temperature': 32.57, 'Humidity': 62.37, 'Air Pressure': 1008.52, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# Error fetching latest data from WS1: ("Connection broken: ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None)", ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
# [WS1] No data found. Waiting for next update...
# Error fetching latest data from WS1: HTTPSConnectionPool(host='oauth2.googleapis.com', port=443): Max retries exceeded with url: /token (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000021D2668B190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# [WS1] No data found. Waiting for next update...
# Error fetching latest data from WS1: HTTPSConnectionPool(host='oauth2.googleapis.com', port=443): Max retries exceeded with url: /token (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000021D23270130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# [WS1] No data found. Waiting for next update...
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:13:24: {'Temperature': 32.56, 'Humidity': 58.02, 'Air Pressure': 1010.72, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:14:41: {'Temperature': 32.26, 'Humidity': 58.14, 'Air Pressure': 1010.69, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:15:27: {'Temperature': 32.32, 'Humidity': 58.06, 'Air Pressure': 1010.66, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:16:08: {'Temperature': 32.15, 'Humidity': 57.97, 'Air Pressure': 1010.67, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:16:49: {'Temperature': 32.67, 'Humidity': 58.29, 'Air Pressure': 1010.66, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:17:31: {'Temperature': 32.43, 'Humidity': 58.39, 'Air Pressure': 1010.64, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:18:15: {'Temperature': 32.25, 'Humidity': 58.31, 'Air Pressure': 1010.62, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:18:56: {'Temperature': 32.23, 'Humidity': 58.4, 'Air Pressure': 1010.63, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:19:39: {'Temperature': 32.62, 'Humidity': 59.01, 'Air Pressure': 1010.65, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:20:28: {'Temperature': 32.65, 'Humidity': 59.06, 'Air Pressure': 1010.67, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:21:11: {'Temperature': 32.47, 'Humidity': 58.9, 'Air Pressure': 1010.67, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:21:51: {'Temperature': 32.64, 'Humidity': 58.27, 'Air Pressure': 1010.65, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:22:32: {'Temperature': 32.64, 'Humidity': 58.27, 'Air Pressure': 1010.65, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:23:15: {'Temperature': 32.41, 'Humidity': 58.15, 'Air Pressure': 1010.68, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:23:55: {'Temperature': 32.52, 'Humidity': 58.5, 'Air Pressure': 1010.63, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:24:35: {'Temperature': 32.5, 'Humidity': 58.46, 'Air Pressure': 1010.65, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11:25:16: {'Temperature': 32.58, 'Humidity': 58.38, 'Air Pressure': 1010.65, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 11
 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 12:36:54: {'Temperature': 32.41, 'Humidity': 56.82, 'Air Pressure': 1009.65, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 12:37:34: {'Temperature': 32.55, 'Humidity': 56.4, 'Air Pressure': 1009.62, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 12:38:14: {'Temperature': 32.41, 'Humidity': 56.58, 'Air Pressure': 1009.57, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 12:38:54: {'Temperature': 32.46, 'Humidity': 56.67, 'Air Pressure': 1009.57, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 12:39:34: {'Temperature': 32.66, 'Humidity': 56.94, 'Air Pressure': 1009.54, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 12:40:14: {'Temperature': 32.38, 'Humidity': 56.87, 'Air Pressure': 1009.56, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ...
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:17:24: {'Temperature': 32.57, 'Humidity': 64.48, 'Air Pressure': 1010.1, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:18:05: {'Temperature': 32.54, 'Humidity': 64.68, 'Air Pressure': 1010.11, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:18:45: {'Temperature': 32.54, 'Humidity': 64.78, 'Air Pressure': 1010.13, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:19:27: {'Temperature': 32.54, 'Humidity': 64.79, 'Air Pressure': 1010.13, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:20:10: {'Temperature': 32.7, 'Humidity': 64.91, 'Air Pressure': 1010.13, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:20:53: {'Temperature': 32.36, 'Humidity': 64.84, 'Air Pressure': 1010.11, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:21:35: {'Temperature': 32.31, 'Humidity': 64.9, 'Air Pressure': 1010.1, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:22:19: {'Temperature': 32.46, 'Humidity': 64.97, 'Air Pressure': 1010.15, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:23:01: {'Temperature': 32.51, 'Humidity': 64.77, 'Air Pressure': 1010.13, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:23:42: {'Temperature': 32.45, 'Humidity': 64.94, 'Air Pressure': 1010.15, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:24:24: {'Temperature': 32.64, 'Humidity': 64.98, 'Air Pressure': 1010.17, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:25:04: {'Temperature': 32.17, 'Humidity': 65.05, 'Air Pressure': 1010.17, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:25:44: {'Temperature': 32.6, 'Humidity': 64.98, 'Air Pressure': 1010.17, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:26:26: {'Temperature': 32.53, 'Humidity': 64.87, 'Air Pressure': 1010.19, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:27:07: {'Temperature': 32.72, 'Humidity': 64.69, 'Air Pressure': 1010.2, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:27:47: {'Temperature': 32.3, 'Humidity': 64.85, 'Air Pressure': 1010.19, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:28:27: {'Temperature': 32.32, 'Humidity': 64.77, 'Air Pressure': 1010.19, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:29:07: {'Temperature': 32.76, 'Humidity': 64.77, 'Air Pressure': 1010.17, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:29:47: {'Temperature': 32.29, 'Humidity': 64.67, 'Air Pressure': 1010.17, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# [WS2] Data unreadable: could not convert string to float: '6\x05.28'. Waiting for valid data...
# [WS2] Data unreadable: could not convert string to float: '6\x05.28'. Waiting for valid data...
# [WS2] Data unreadable: could not convert string to float: '6\x05.28'. Waiting for valid data...
# [WS2] Data unreadable: could not convert string to float: '6\x05.28'. Waiting for valid data...
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:31:26: {'Temperature': 32.83, 'Humidity': 64.67, 'Air Pressure': 1010.16, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:32:06: {'Temperature': 32.62, 'Humidity': 64.73, 'Air Pressure': 1010.16, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:32:46: {'Temperature': 32.59, 'Humidity': 64.66, 'Air Pressure': 1010.16, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:33:27: {'Temperature': 32.34, 'Humidity': 64.8, 'Air Pressure': 1010.16, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:34:08: {'Temperature': 32.75, 'Humidity': 64.59, 'Air Pressure': 1010.17, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:34:52: {'Temperature': 32.75, 'Humidity': 64.64, 'Air Pressure': 1010.16, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:35:33: {'Temperature': 32.75, 'Humidity': 64.64, 'Air Pressure': 1010.16, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:36:13: {'Temperature': 32.61, 'Humidity': 64.65, 'Air Pressure': 1010.16, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ✅ Updated Predictions for Location (7.01957, 79.9002561) at 2025-04-19 21:36:54: {'Temperature': 32.58, 'Humidity': 64.6, 'Air Pressure': 1010.19, 'Air Quality': 'Poor', 'Rain Status': 'Not raining'}
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# D:\anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# D:\anaconda\lib\http\client.py in getresponse(self)
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#
# D:\anaconda\lib\http\client.py in begin(self)
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#
# D:\anaconda\lib\http\client.py in _read_status(self)
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#
# D:\anaconda\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# D:\anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#
# D:\anaconda\lib\ssl.py in read(self, len, buffer)
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# D:\anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     549             if read is False or not self._is_method_retryable(method):
# --> 550                 raise six.reraise(type(error), error, _stacktrace)
#     551             elif read is not None:
#
# D:\anaconda\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# D:\anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# D:\anaconda\lib\http\client.py in getresponse(self)
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#
# D:\anaconda\lib\http\client.py in begin(self)
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#
# D:\anaconda\lib\http\client.py in _read_status(self)
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#
# D:\anaconda\lib\socket.py in readinto(self, b)
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#
# D:\anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#
# D:\anaconda\lib\ssl.py in read(self, len, buffer)
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#
# ProtocolError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34328\1541498615.py in <module>
#     162 # Start predictions
#     163 try:
# --> 164     update_predictions()
#     165 except KeyboardInterrupt:
#     166     print("Prediction update process stopped.")
#
# ~\AppData\Local\Temp\ipykernel_34328\1541498615.py in update_predictions()
#     155             predictions['Air Quality'], predictions['Rain Status']
#     156         ]
# --> 157         pd_sheet.append_row(new_row)
#     158
#     159         print(f"✅ Updated Predictions for Location ({target_location['latitude']}, {target_location['longitude']}) at {current_time}: {predictions}")
#
# D:\anaconda\lib\site-packages\gspread\worksheet.py in append_row(self, values, value_input_option, insert_data_option, table_range, include_values_in_response)
#    1806
#    1807         """
# -> 1808         return self.append_rows(
#    1809             [values],
#    1810             value_input_option=value_input_option,
#
# D:\anaconda\lib\site-packages\gspread\worksheet.py in append_rows(self, values, value_input_option, insert_data_option, table_range, include_values_in_response)
#    1856         body = {"values": values}
#    1857
# -> 1858         res = self.client.values_append(self.spreadsheet_id, range_label, params, body)
#    1859         num_new_rows = len(values)
#    1860         self._properties["gridProperties"]["rowCount"] += num_new_rows
#
# D:\anaconda\lib\site-packages\gspread\http_client.py in values_append(self, id, range, params, body)
#     189         """
#     190         url = SPREADSHEET_VALUES_APPEND_URL % (id, quote(range))
# --> 191         r = self.request("post", url, params=params, json=body)
#     192         return r.json()
#     193
#
# D:\anaconda\lib\site-packages\gspread\http_client.py in request(self, method, endpoint, params, data, json, files, headers)
#     112         headers: Optional[MutableMapping[str, str]] = None,
#     113     ) -> Response:
# --> 114         response = self.session.request(
#     115             method=method,
#     116             url=endpoint,
#
# D:\anaconda\lib\site-packages\google\auth\transport\requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     535
#     536         with TimeoutGuard(remaining_time) as guard:
# --> 537             response = super(AuthorizedSession, self).request(
#     538                 method,
#     539                 url,
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     545
#     546         except (ProtocolError, OSError) as err:
# --> 547             raise ConnectionError(err, request=request)
#     548
#     549         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
